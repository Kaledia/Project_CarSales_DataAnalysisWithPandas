# %%
# Project to analyze data with Pandas Python: data cleaning (find and fill null, remove unwanted data), data exploration (value counts, filtering), data manipulation (applying functions), data visualisation (plot, histogram)
# Thanks to the Youtube Channel "Data Science Lovers" for the data: https://drive.google.com/file/d/1MlrQ... 

# Import operating system, numpy and pandas libraries
import os
import pandas as pd 
import numpy as np

# Check current working library
os.getcwd()

# Import csv data from local repository 
car=pd.read_csv ("Cars_Data.csv")

# Check if data was successfully imported
car
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
print (car[car['Make'].isnull()])
# Out:
#     Make Model Type Origin DriveTrain MSRP Invoice  EngineSize  Cylinders  \
# 30   NaN   NaN  NaN    NaN        NaN  NaN     NaN         NaN        NaN
# 39   NaN   NaN  NaN    NaN        NaN  NaN     NaN         NaN        NaN
# 161  NaN   NaN  NaN    NaN        NaN  NaN     NaN         NaN        NaN
# 173  NaN   NaN  NaN    NaN        NaN  NaN     NaN         NaN        NaN
#
#      Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 30          NaN       NaN          NaN     NaN        NaN     NaN
# 39          NaN       NaN          NaN     NaN        NaN     NaN
# 161         NaN       NaN          NaN     NaN        NaN     NaN
# 173         NaN       NaN          NaN     NaN        NaN     NaN

# %%
print (car[car['Cylinders'].isnull()])
# Out:
#       Make               Model    Type Origin DriveTrain      MSRP   Invoice  \
# 30     NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 39     NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 161    NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 173    NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 251  Mazda  RX-8 4dr automatic  Sports   Asia       Rear  $25,700   $23,794
# 252  Mazda     RX-8 4dr manual  Sports   Asia       Rear  $27,200   $25,179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 30          NaN        NaN         NaN       NaN          NaN     NaN
# 39          NaN        NaN         NaN       NaN          NaN     NaN
# 161         NaN        NaN         NaN       NaN          NaN     NaN
# 173         NaN        NaN         NaN       NaN          NaN     NaN
# 251         1.3        NaN       197.0      18.0         25.0  3053.0
# ...

# %%
car_noNaN= car[car.Make.notnull()]

# %%
car_noNaN.isna().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# As the two cars with missing cylinders values are Mazda, print Mazda data
print (car_noNaN[car_noNaN['Make'] == 'Mazda'])
# Out:
#       Make                          Model    Type Origin DriveTrain      MSRP  \
# 244  Mazda                 Tribute DX 2.0     SUV   Asia        All  $21,087
# 245  Mazda                   Mazda3 i 4dr   Sedan   Asia      Front  $15,500
# 246  Mazda                   Mazda3 s 4dr   Sedan   Asia      Front  $17,200
# 247  Mazda                   Mazda6 i 4dr   Sedan   Asia      Front  $19,270
# 248  Mazda                         MPV ES   Sedan   Asia      Front  $28,750
# 249  Mazda     MX-5 Miata convertible 2dr  Sports   Asia       Rear  $22,388
# 250  Mazda  MX-5 Miata LS convertible 2dr  Sports   Asia       Rear  $25,193
# 251  Mazda             RX-8 4dr automatic  Sports   Asia       Rear  $25,700
# 252  Mazda                RX-8 4dr manual  Sports   Asia       Rear  $27,200
# 253  Mazda           B2300 SX Regular Cab   Truck   Asia       Rear  $14,840
# 254  Mazda              B4000 SE Cab Plus   Truck   Asia        All  $22,350
#
# ...

# %%
# As the 2 missing cylinders values are for a 1.3 engineSize, I assume that it is 4 cylinders (Google confirm that a Mazda RX8 is a 4 cylinder car)
car_noNaN['Cylinders'].fillna(4, inplace=True)
# Out:
# C:\Users\Kaledia\AppData\Local\Temp\ipykernel_299696\1327941148.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_noNaN['Cylinders'].fillna(4, inplace=True)

# %%
car['Cylinders'].fillna(4, inplace=True)

# %%
print (car_noNaN[car_noNaN['Make'] == 'Mazda'])
# Out:
#       Make                          Model    Type Origin DriveTrain      MSRP  \
# 244  Mazda                 Tribute DX 2.0     SUV   Asia        All  $21,087
# 245  Mazda                   Mazda3 i 4dr   Sedan   Asia      Front  $15,500
# 246  Mazda                   Mazda3 s 4dr   Sedan   Asia      Front  $17,200
# 247  Mazda                   Mazda6 i 4dr   Sedan   Asia      Front  $19,270
# 248  Mazda                         MPV ES   Sedan   Asia      Front  $28,750
# 249  Mazda     MX-5 Miata convertible 2dr  Sports   Asia       Rear  $22,388
# 250  Mazda  MX-5 Miata LS convertible 2dr  Sports   Asia       Rear  $25,193
# 251  Mazda             RX-8 4dr automatic  Sports   Asia       Rear  $25,700
# 252  Mazda                RX-8 4dr manual  Sports   Asia       Rear  $27,200
# 253  Mazda           B2300 SX Regular Cab   Truck   Asia       Rear  $14,840
# 254  Mazda              B4000 SE Cab Plus   Truck   Asia        All  $22,350
#
# ...

# %%
car_noNaN.isna().sum().plot(kind='bar')
car.isna().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
car_noNaN.isna().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Data Exploration: Count the number of model by make
car_noNaN['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
# Filtering all records where origin is Asia or Europe
car_noNaN[car_noNaN['Origin'].isin(['Asia', 'Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
# Create a new column with Combined MPG
car_noNaN["MPG_Combined"]= car_noNaN["MPG_City"] + car_noNaN[MPG_Highway"]
# Out:
#   File "C:\Users\Kaledia\AppData\Local\Temp\ipykernel_299696\1483323574.py", line 2
#     car_noNaN["MPG_Combined"]= car_noNaN["MPG_City"] + car_noNaN[MPG_Highway"]
#                                                                               ^
# SyntaxError: EOL while scanning string literal

# %%
type(car_noNaN["MPG_City"])
# Out:
# pandas.core.series.Series

# %%
# Convert to numeric the string 
car[["EngineSize", "Cylinders", "Horsepower", "MPG_City", "MPG_Highway", "Weight", "Wheelbase", "Length"]] = car[["EngineSize", "Cylinders", "Horsepower", "MPG_City", "MPG_Highway", "Weight", "Wheelbase", "Length"]].apply(pd.to_numeric)

# %%
car["MPG_Combined"]= car["MPG_City"] + car["MPG_Highway"]

# %%
print(car_noNaN)
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...
